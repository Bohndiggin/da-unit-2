# %% [markdown]
# # Unit 2 Project - Data Cleaning

# %% [markdown]
# ## Part 1: Prepare Environment and Jupyter Notebook

# %% [markdown]
# ### Step 1: Create Virtual Environment
#
# This step should have been completed prior to opening the Jupyter Notebook. Refer to project instructions.

# %%
import pandas as pd
import seaborn as sns
import numpy as np
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ### Step 2: Open Jupyter Notebook File
#
# Congratulations! If you're here it means you have completed Step 2.

# %% [markdown]
# ### Step 3: Load .csv Files into DataFrames

# %%
####### TO DO ########

# load house_data.csv into a dataframe using pd.read_csv()

house_data = pd.read_csv('house_data.csv')

# load house_sales.csv into a dataframe using pd.read_csv()

house_sales = pd.read_csv('house_sales.csv')

######################

# %%
###### TO DO ######

# use .head() on your new dataframe to show the dataframe was loaded succussfully

house_data.head()
# Out:
#    Unnamed: 0          ID  Bedrooms  Bathrooms  SQFT living  SQFT lot  Floors  \
# 0           0  7129300520         3       1.00         1180    5650.0     1.0
# 1           1  6414100192         3       2.25         2570    7242.0     2.0
# 2           2  5631500400         2       1.00          770   10000.0     1.0
# 3           3  2487200875         4       3.00         1960    5000.0     1.0
# 4           4  1954400510         3       2.00         1680    8080.0     1.0
#
#   Waterfront?       View  House Condition  Grade  SQFT above  SQFT basement  \
# 0          No  Very Poor     OK Condition    7.0      1180.0              0
# 1          No  Very Poor     OK Condition    7.0      2170.0            400
# 2          No  Very Poor     OK Condition    6.0       770.0              0
# 3          No  Very Poor  Great Condition    7.0      1050.0            910
# 4          No  Very Poor     OK Condition    8.0      1680.0              0
#
# ...

# %%
###### TO DO ######

# use .head() on your second new dataframe to show the dataframe was loaded succussfully

house_sales.head()
# Out:
#    Unnamed: 0          Id             DATE        Price
# 0           0  7129300520  20141013T000000  $221,900.00
# 1           1  6414100192  20141209T000000  $538,000.00
# 2           2  5631500400  20150225T000000  $180,000.00
# 3           3  2487200875  20141209T000000  $604,000.00
# 4           4  1954400510  20150218T000000  $510,000.00

# %%
df1.dtypes
# Out:
# id                  object
# bedrooms             int64
# bathrooms          float64
# sqft_living          int64
# sqft_lot           float64
# floors             float64
# waterfront           int64
# view                 int64
# house_condition      int64
# grade              float64
# sqft_above         float64
# sqft_basement        int64
# year_built         float64
# zipcode             object
# lat                float64
# long               float64
# sqft_living_15       int64
# sqft_lot_15          int64
# dtype: object

# %% [markdown]
# ### Step 4: Create Data Dictionaries for Each Dataset

# %%
####### TO DO ###########

# Work in the cells below to fill in missing information in the data dictionary.

# %% [markdown]
# #### Data Dictionary - House Data
#
# **id**: An ID
# > Description: ID
# >
# > Data type: int64
#
# **bedrooms**:
# > Description: Number of bedrooms in house
# >
# > Data type: int64
#
# **bathrooms**:
# > Description: Number of bathrooms in house
# >
# > Data type: float64
#
# **sqft_living**:
# > Description: How much sqft there is inside
# >
# > Data type: int64
#
# **sqft_lot**:
# > Description: sqft of the whole lot
# >
# > Data type: float64
#
# **floors**:
# > Description: How many floors the house is
# >
# > Data type: float64 (for some reason)
#
# **waterfront**:
# > Description: Is the house by the water
# >
# > Data type: object (str) (should be boolean)
#
# **view**:
# > Description: Is there a good view outside the windows of the house
# >
# > Data type: object (str)
#
# **condition**:
# > Description: A str denoting the condition of the house
# >
# > Data type: obj (str)
#
# **grade**:
# > Description: A score to rank the house
# >
# > Data type: float64
#
# **sqft_above**:
# > Description: How much sqft is above the ground
# >
# > Data type: float64
#
# **sqft_basement**:
# > Description: How much sqft is below ground
# >
# > Data type: int64
#
# **yr_built**:
# > Description: When was the building built
# >
# > Data type: float64
#
# **yr_renovated**:
# > Description: When was the building renovated (note: lots of NaN)
# >
# > Data type: float64
#
# **zipcode**:
# > Description: What zipcode is the building in?
# >
# > Data type: float64
#
# **lat**:
# > Description: latitude
# >
# > Data type: float64
#
# **long**:
# > Description: longitude
# >
# > Data type: float64
#
# **sqft_living15**:
# > Description: avg sqft of nearest 15 neighbors
# >
# > Data type: int64
#
# **sqft_lot15**:
# > Description: avg sqft of the lot of the nearest 15 neighbors
# >
# > Data type: int64

# %%
df2.dtypes
# Out:
# id        object
# date      object
# price    float64
# dtype: object

# %% [markdown]
# #### Data Dictionary - House Sales Data
#
# **id**:
# > Description: identity
# >
# > Data type: int64
#
# **date**:
# > Description: date of sale
# >
# > Data type: object >:(
#
# **price**:
# > Description: price sold for
# >
# > Data type: object (str) -____-

# %% [markdown]
# ### Step 5: Create Copies of DataFrames to Start Cleaning Process

# %%
###### TO DO ######

# create a copy of house_data

df1 = house_data.copy()

# create a copy of sales_data

df2 = house_sales.copy()

# %%
###### TO DO ######

# use .head() on your new dataframe to show the dataframe was copied succussfully

df1.head()
# Out:
#    Unnamed: 0          ID  Bedrooms  Bathrooms  SQFT living  SQFT lot  Floors  \
# 0           0  7129300520         3       1.00         1180    5650.0     1.0
# 1           1  6414100192         3       2.25         2570    7242.0     2.0
# 2           2  5631500400         2       1.00          770   10000.0     1.0
# 3           3  2487200875         4       3.00         1960    5000.0     1.0
# 4           4  1954400510         3       2.00         1680    8080.0     1.0
#
#   Waterfront?       View  House Condition  Grade  SQFT above  SQFT basement  \
# 0          No  Very Poor     OK Condition    7.0      1180.0              0
# 1          No  Very Poor     OK Condition    7.0      2170.0            400
# 2          No  Very Poor     OK Condition    6.0       770.0              0
# 3          No  Very Poor  Great Condition    7.0      1050.0            910
# 4          No  Very Poor     OK Condition    8.0      1680.0              0
#
# ...

# %%
###### TO DO ######

# use .head() on your second new dataframe to show the dataframe was copied succussfully

df2.head()
# Out:
#    Unnamed: 0          Id             DATE        Price
# 0           0  7129300520  20141013T000000  $221,900.00
# 1           1  6414100192  20141209T000000  $538,000.00
# 2           2  5631500400  20150225T000000  $180,000.00
# 3           3  2487200875  20141209T000000  $604,000.00
# 4           4  1954400510  20150218T000000  $510,000.00

# %% [markdown]
# ## Part 2: Assess Data and Create Data Cleaning Plan

# %% [markdown]
# ### Step 1: Check Column Names, Casing, Spelling, Etc.

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########


# print(df2.columns)

# df1.columns = df1.columns.str.lower()
# df2.columns = df2.columns.str.lower()

'''
plan: lotsa unification needed
'''

df1.info()
df1.head()
# Out:
# '\nplan: lotsa unification needed\n'
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       21613 non-null  int64
#  1   ID               21613 non-null  int64
#  2   Bedrooms         21613 non-null  int64
#  3   Bathrooms        21611 non-null  float64
#  4   SQFT living      21613 non-null  int64
#  5   SQFT lot         21611 non-null  float64
#  6   Floors           21613 non-null  float64
#  7   Waterfront?      21605 non-null  object
#  8   View             21611 non-null  object
#  9   House Condition  21607 non-null  object
#  10  Grade            21611 non-null  float64
#  11  SQFT above       21612 non-null  float64
#  12  SQFT basement    21613 non-null  int64
#  13  Year Built       21612 non-null  float64
#  14  Year Renovated   21276 non-null  float64
# ...

# %%
df2.info()
df2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  21613 non-null  int64
#  1   Id          21613 non-null  int64
#  2   DATE        21613 non-null  object
#  3   Price       21609 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 675.5+ KB
#    Unnamed: 0          Id             DATE        Price
# 0           0  7129300520  20141013T000000  $221,900.00
# 1           1  6414100192  20141209T000000  $538,000.00
# 2           2  5631500400  20150225T000000  $180,000.00
# 3           3  2487200875  20141209T000000  $604,000.00
# 4           4  1954400510  20150218T000000  $510,000.00

# %% [markdown]
# ### Step 2: Validate Data Types

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# df1.unique()

# %% [markdown]
# Q: Do any of the data types in the dataframe need to be changed?

# %% [markdown]
# A: df1 needs zipcode to be a str, dates need to be datetime
# df2 needs price and date fixed and id turned into a str

# %% [markdown]
# ### Step 3: Detect Missing Values

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

df1.isnull().sum()
# Out:
# Unnamed: 0           0
# ID                   0
# Bedrooms             0
# Bathrooms            2
# SQFT living          0
# SQFT lot             2
# Floors               0
# Waterfront?          8
# View                 2
# House Condition      6
# Grade                2
# SQFT above           1
# SQFT basement        0
# Year Built           1
# Year Renovated     337
# Zipcode              3
# Lat                  1
# Long                 1
# SQFT living 15       0
# SQFT lot 15          0
# dtype: int64

# %%
df1.isna().sum()
# Out:
# Unnamed: 0           0
# ID                   0
# Bedrooms             0
# Bathrooms            2
# SQFT living          0
# SQFT lot             2
# Floors               0
# Waterfront?          8
# View                 2
# House Condition      6
# Grade                2
# SQFT above           1
# SQFT basement        0
# Year Built           1
# Year Renovated     337
# Zipcode              3
# Lat                  1
# Long                 1
# SQFT living 15       0
# SQFT lot 15          0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0    0
# Id            0
# DATE          0
# Price         4
# dtype: int64

# %%
df2.isna().sum()
# Out:
# Unnamed: 0    0
# Id            0
# DATE          0
# Price         4
# dtype: int64

# %% [markdown]
# Q: Which variables/columns have missing values?

# %% [markdown]
# A:
# > df1.Bathrooms
#
# > df1.SQFT lot
#
# > df1.Waterfront?
#
# > df1.View
#
# > df1.House Condition
#
# > df1.Grade
#
# > df1.Year Built
#
# > df1.Year Renovated
#
# > df1.zipcode
#
# > df1.lat
#
# > df1.long
#
# > df2.price

# %% [markdown]
# ### Step 4: Detect Outliers

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       21613 non-null  int64
#  1   ID               21613 non-null  int64
#  2   Bedrooms         21613 non-null  int64
#  3   Bathrooms        21611 non-null  float64
#  4   SQFT living      21613 non-null  int64
#  5   SQFT lot         21611 non-null  float64
#  6   Floors           21613 non-null  float64
#  7   Waterfront?      21605 non-null  object
#  8   View             21611 non-null  object
#  9   House Condition  21607 non-null  object
#  10  Grade            21611 non-null  float64
#  11  SQFT above       21612 non-null  float64
#  12  SQFT basement    21613 non-null  int64
#  13  Year Built       21612 non-null  float64
#  14  Year Renovated   21276 non-null  float64
#  15  Zipcode          21610 non-null  float64
# ...

# %% [markdown]
# Q: Which variables/columns have outliers?

# %% [markdown]
# A:
# > df1.bedrooms
#
# > df1.bathrooms
#
# > df1.sqft_living
#
# > df1.SQFT lot
#
# > df1.grade
#
# > df1.sqft_above
#
# > df1.sqft_basement
#
# > df1.year_built
#
# > df1.year_renovated (likely due to NaN)
#
# > df1.sqft_living_15
#
# > df1.sqft_lot_15

# %%
sns.boxplot(x=df1["SQFT lot 15"])
# Out:
# <AxesSubplot:xlabel='SQFT lot 15'>

# %% [markdown]
# ### Step 5: Write Data Cleaning Plan

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# #### Data Cleaning Plan:
#
# - clean column names
# - reassign dtypes
# - treat missing values
# - get rid of outliers

# %% [markdown]
# ## Part 3: Execute Data Cleaning Plan Using DEFINE / CLEAN / TEST Approach

# %% [markdown]
# ### Step 1: Understand DEFINE / CLEAN / TEST Approach

# %% [markdown]
# Refer to project instructions for an explanation of this step. You can copy and past the template in the cell below to use in each step of Part 3 as you are treating the issues you found in the data.

# %%
### DEFINE ###

# what you are going to do and why

### CLEAN ### 

# python functions to execute

### TEST ###

# testing to ensure success

# %% [markdown]
# ### Step 2: Treat Names / Casing / Spelling Issues

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       21613 non-null  int64
#  1   ID               21613 non-null  int64
#  2   Bedrooms         21613 non-null  int64
#  3   Bathrooms        21611 non-null  float64
#  4   SQFT living      21613 non-null  int64
#  5   SQFT lot         21611 non-null  float64
#  6   Floors           21613 non-null  float64
#  7   Waterfront?      21605 non-null  object
#  8   View             21611 non-null  object
#  9   House Condition  21607 non-null  object
#  10  Grade            21611 non-null  float64
#  11  SQFT above       21612 non-null  float64
#  12  SQFT basement    21613 non-null  int64
#  13  Year Built       21612 non-null  float64
#  14  Year Renovated   21276 non-null  float64
#  15  Zipcode          21610 non-null  float64
# ...

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
### DEFINE ###

# I Need to rename all the columns first so I can deal with them. We can also drop Unnamed: 0

### CLEAN ### 

def snake_case(dataframe):
    dataframe.columns = dataframe.columns.str.lower()
    dataframe.columns = dataframe.columns.str.replace(r'[^\w\s]+', '')
    dataframe.columns = dataframe.columns.str.replace(' ', '_')
    return dataframe
    
    


df1 = snake_case(df1)
df2 = snake_case(df2)

df1.drop(df1.columns[[0]], axis=1, inplace=True)
df2.drop(df2.columns[[0]], axis=1, inplace=True)

### TEST ###

df2.head()
# Out:
# C:\Users\bohnd\AppData\Local\Temp\ipykernel_2556\612846046.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   dataframe.columns = dataframe.columns.str.replace(r'[^\w\s]+', '')
# C:\Users\bohnd\AppData\Local\Temp\ipykernel_2556\612846046.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   dataframe.columns = dataframe.columns.str.replace(r'[^\w\s]+', '')
#            id             date        price
# 0  7129300520  20141013T000000  $221,900.00
# 1  6414100192  20141209T000000  $538,000.00
# 2  5631500400  20150225T000000  $180,000.00
# 3  2487200875  20141209T000000  $604,000.00
# 4  1954400510  20150218T000000  $510,000.00

# %% [markdown]
# ### Step 2.5: dtypes

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               21613 non-null  int64
#  1   bedrooms         21613 non-null  int64
#  2   bathrooms        21611 non-null  float64
#  3   sqft_living      21613 non-null  int64
#  4   sqft_lot         21611 non-null  float64
#  5   floors           21613 non-null  float64
#  6   waterfront       21605 non-null  object
#  7   view             21611 non-null  object
#  8   house_condition  21607 non-null  object
#  9   grade            21611 non-null  float64
#  10  sqft_above       21612 non-null  float64
#  11  sqft_basement    21613 non-null  int64
#  12  year_built       21612 non-null  float64
#  13  year_renovated   21276 non-null  float64
#  14  zipcode          21610 non-null  float64
#  15  lat              21612 non-null  float64
# ...

# %%
### DEFINE ###

#some datatypes need to be changed

### CLEAN ### 

df1 = df1.astype({'id': 'str', 'zipcode': 'str'})
pd.to_datetime(df1['year_built'])
df2.head()
df2 = df2.astype({'id': 'str'})
df2['price'] = df2['price'].str.replace('$', '')
df2['price'] = df2['price'].str.replace(',', '')
df2 = df2.astype({'price': 'float'})
df2.head()

### TEST ###

# df1.info()
# Out:
# 0       1970-01-01 00:00:00.000001955
# 1       1970-01-01 00:00:00.000001951
# 2       1970-01-01 00:00:00.000001933
# 3       1970-01-01 00:00:00.000001965
# 4       1970-01-01 00:00:00.000001987
#                      ...
# 21608   1970-01-01 00:00:00.000002009
# 21609   1970-01-01 00:00:00.000002014
# 21610                             NaT
# 21611   1970-01-01 00:00:00.000002004
# 21612   1970-01-01 00:00:00.000002008
# Name: year_built, Length: 21613, dtype: datetime64[ns]
#            id             date        price
# 0  7129300520  20141013T000000  $221,900.00
# 1  6414100192  20141209T000000  $538,000.00
# 2  5631500400  20150225T000000  $180,000.00
# 3  2487200875  20141209T000000  $604,000.00
# 4  1954400510  20150218T000000  $510,000.00
# ...

# %% [markdown]
# ### Step 3: Treat Missing Values

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
### DEFINE ###

#time to clean up the empties
#most will be filled with the mean others will be explained

### CLEAN ### 

df1.bathrooms = df1.bathrooms.fillna(1) # should fill with 1, as most houses have at least 1.
df1.sqft_lot = df1.sqft_lot.fillna(df1.sqft_lot.mean())
df1.waterfront = df1.waterfront.fillna("No") # It's safe to assume that they'd indicate if it was
view_mode = df1.view.mode()
df1.view = df1.view.fillna(value=view_mode[0])
house_condition_mode = df1.house_condition.mode()
df1.house_condition = df1.house_condition.fillna(house_condition_mode[0])
grade_mode = df1.grade.mode()
df1.grade = df1.grade.fillna(grade_mode[0])
df1.sqft_above = df1.sqft_above.fillna(df1.sqft_above.mean())
df1.dropna(subset=['year_built'], inplace=True)
df1.drop(columns=['year_renovated'], inplace=True)
df1.dropna(subset=['lat', 'long'], inplace=True)
df2.dropna(subset=['price'], inplace=True)
df1.drop_duplicates(inplace=True)
# df1.drop(df1[df1.year_renovated > df1.year_built].index, inplace=True)
df2.drop_duplicates(inplace=True)

### TEST ###

# df1.isnull().sum()
# df2.isnull().sum()
# df2.head()

# %% [markdown]
# ### Step 4: Treat Outliers

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

from scipy.stats import zscore

# %%
#observe:

outliers_arr = ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'grade', 'sqft_above', 'sqft_basement', 'year_built', 'sqft_living_15', 'sqft_lot_15']

for i in outliers_arr:
    df1[f'{i}_zscore'] = zscore(df1[f'{i}'])



df1.head()
# Out:
#            id  bedrooms  bathrooms  sqft_living  sqft_lot  floors waterfront  \
# 0  7129300520         3       1.00         1180    5650.0     1.0         No
# 1  6414100192         3       2.25         2570    7242.0     2.0         No
# 2  5631500400         2       1.00          770   10000.0     1.0         No
# 3  2487200875         4       3.00         1960    5000.0     1.0         No
# 4  1954400510         3       2.00         1680    8080.0     1.0         No
#
#         view  house_condition  grade  ...  bedrooms_zscore  bathrooms_zscore  \
# 0  Very Poor     OK Condition    7.0  ...        -0.393900         -1.448242
# 1  Very Poor     OK Condition    7.0  ...        -0.393900          0.171301
# 2  Very Poor     OK Condition    6.0  ...        -1.450096         -1.448242
# 3  Very Poor  Great Condition    7.0  ...         0.662297          1.143026
# 4  Very Poor     OK Condition    8.0  ...        -0.393900         -0.152608
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21435 entries, 0 to 21612
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     21435 non-null  object
#  1   bedrooms               21435 non-null  int64
#  2   bathrooms              21435 non-null  float64
#  3   sqft_living            21435 non-null  int64
#  4   sqft_lot               21435 non-null  float64
#  5   floors                 21435 non-null  float64
#  6   waterfront             21435 non-null  object
#  7   view                   21435 non-null  object
#  8   house_condition        21435 non-null  object
#  9   grade                  21435 non-null  float64
#  10  sqft_above             21435 non-null  float64
#  11  sqft_basement          21435 non-null  int64
#  12  year_built             21435 non-null  float64
#  13  zipcode                21435 non-null  object
# ...

# %%
# df1.query('year_renovated > year_built')

# %%
### DEFINE ###

# now that we have the zscore for all the columns with outliers it's time to cut it down.

### CLEAN ### 

# num = '2'

for i in outliers_arr:
    if i == 'year_renovated': # not relevant to sort out.
        df1.drop(df1[(df1[f'{i}_zscore'] > 4) | (df1[f'{i}_zscore'] < -4)].index, inplace=True)
    else:
        df1.drop(df1[(df1[f'{i}_zscore'] > 3) | (df1[f'{i}_zscore'] < -3)].index, inplace=True)

# for i in outliers_arr:
#     df1.query(f'{i}_zscore > 3 or {i}_zscore < -3')

# df1.query('bathrooms_zscore > 3 or bathrooms_zscore < -3')
# df1.drop(df1[(df1.bathrooms_zscore > 3) | (df1.bathrooms_zscore < -3)].index)

### TEST ###

# df1.query('bathrooms_zscore > 3 or bathrooms_zscore < -3')

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20335 entries, 0 to 21612
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     20335 non-null  object
#  1   bedrooms               20335 non-null  int64
#  2   bathrooms              20335 non-null  float64
#  3   sqft_living            20335 non-null  int64
#  4   sqft_lot               20335 non-null  float64
#  5   floors                 20335 non-null  float64
#  6   waterfront             20335 non-null  object
#  7   view                   20335 non-null  object
#  8   house_condition        20335 non-null  object
#  9   grade                  20335 non-null  float64
#  10  sqft_above             20335 non-null  float64
#  11  sqft_basement          20335 non-null  int64
#  12  year_built             20335 non-null  float64
#  13  zipcode                20335 non-null  object
# ...

# %% [markdown]
# ### Step 5: Summarize Actions Taken & Justify Approach

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# 1. I cleaned up the coulumn titles to make more sense and be easily readable
# 2. I fixed the dtypes to fit standard conventions
# 3. Cleaned up missing values making sure to replace what I needed to.
# 4. OUtliers were treated. Most were kept to between a zscore of -3 and 3. Remodeling/renovation wasn't because renovations are less common to do.
# 5. done!

# %% [markdown]
# ## Part 4: Re-Express Categorical Variables

# %% [markdown]
# ### Step 1: Determine Which Variables Need to Be Re-Expressed

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20335 entries, 0 to 21612
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     20335 non-null  object
#  1   bedrooms               20335 non-null  int64
#  2   bathrooms              20335 non-null  float64
#  3   sqft_living            20335 non-null  int64
#  4   sqft_lot               20335 non-null  float64
#  5   floors                 20335 non-null  float64
#  6   waterfront             20335 non-null  object
#  7   view                   20335 non-null  object
#  8   house_condition        20335 non-null  object
#  9   grade                  20335 non-null  float64
#  10  sqft_above             20335 non-null  float64
#  11  sqft_basement          20335 non-null  int64
#  12  year_built             20335 non-null  float64
#  13  zipcode                20335 non-null  object
# ...

# %% [markdown]
# List categorical variables which need to be re-expressed here:
#
# 1. waterfront
# 2. view
# 3. house_condition

# %%
df1.house_condition.unique()
# Out:
# array(['OK Condition', 'Great Condition', 'Good Condition',
#        'Very Bad Condition', 'Bad Condition'], dtype=object)

# %% [markdown]
# ### Step 2: Choose Method to Re-Express Variables

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# Edit this cell to explain which method you are choosing to re-express each variable and why.
# 1. waterfront - can be a binary value
# 2. view
#     1. 'Very Poor'
#     2. 'Poor'
#     3. 'Neutral'
#     4. 'Good'
#     5. 'Great'
# 3. house_condition
#     1. 'Very Bad Condition'
#     2. 'Bad Condition'
#     3. 'OK Condition'
#     4. 'Good Condition'
#     5. 'Great Condition'

# %% [markdown]
# ### Step 3: Perform Transformation

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########


waterfront_dictionary = {
    'No': 0,
    'Yes': 1
}

view_dictionary = {
    'Very Poor': 1,
    'Poor': 2,
    'Neutral': 3,
    'Good': 4,
    'Great': 5
}

condition_dictionary = {
    'Very Bad Condition': 1,
    'Bad Condition': 2,
    'OK Condition': 3,
    'Good Condition': 4,
    'Great Condition': 5
}

df1.waterfront = df1.waterfront.map(waterfront_dictionary).astype('int64')
df1.view = df1.view.map(view_dictionary).astype('int64')
df1.house_condition = df1.house_condition.map(condition_dictionary).astype('int64')

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20335 entries, 0 to 21612
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     20335 non-null  object
#  1   bedrooms               20335 non-null  int64
#  2   bathrooms              20335 non-null  float64
#  3   sqft_living            20335 non-null  int64
#  4   sqft_lot               20335 non-null  float64
#  5   floors                 20335 non-null  float64
#  6   waterfront             20335 non-null  int64
#  7   view                   20335 non-null  int64
#  8   house_condition        20335 non-null  int64
#  9   grade                  20335 non-null  float64
#  10  sqft_above             20335 non-null  float64
#  11  sqft_basement          20335 non-null  int64
#  12  year_built             20335 non-null  float64
#  13  zipcode                20335 non-null  object
# ...

# %% [markdown]
# ### Step 4: Summarize Actions Taken & Justify Approach

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# Edit this cell to add your summary and justification per project instructions.
#
# Assigning numerical values to each was better than creating a new column for each instance as it keeps the data simple.

# %%
df1.columns

df1.drop(['bedrooms_zscore',
       'bathrooms_zscore', 'sqft_living_zscore', 'sqft_lot_zscore',
       'grade_zscore', 'sqft_above_zscore', 'sqft_basement_zscore',
       'year_built_zscore', 'sqft_living_15_zscore',
       'sqft_lot_15_zscore'],axis=1, inplace=True)
# Out:
# Index(['id', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'house_condition', 'grade', 'sqft_above',
#        'sqft_basement', 'year_built', 'zipcode', 'lat', 'long',
#        'sqft_living_15', 'sqft_lot_15', 'bedrooms_zscore', 'bathrooms_zscore',
#        'sqft_living_zscore', 'sqft_lot_zscore', 'grade_zscore',
#        'sqft_above_zscore', 'sqft_basement_zscore', 'year_built_zscore',
#        'sqft_living_15_zscore', 'sqft_lot_15_zscore'],
#       dtype='object')

# %% [markdown]
# ## Part 5: Combine Datasets into Master DataFrame

# %% [markdown]
# ### Step 1: Choose Method to Merge DataFrames into New Master DataFrame

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# Edit this cell to explain which method you are choosing to merge the data and why.
#
# I'm going to join on the id as it's equal across datasets.

# %% [markdown]
# ### Step 2: Merge DataFrames

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

master_df = df2.merge(df1, on="id")

# %%
# Use .head() method to print first few rows of new master dataframe

master_df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  house_condition  grade  sqft_above  \
# 0    5650.0     1.0           0     1                3    7.0      1180.0
# 1    7242.0     2.0           0     1                3    7.0      2170.0
# 2   10000.0     1.0           0     1                3    6.0       770.0
# 3    5000.0     1.0           0     1                5    7.0      1050.0
# 4    8080.0     1.0           0     1                3    8.0      1680.0
#
# ...

# %% [markdown]
# ### Step 3: Save Master DataFrame to New .CSV

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

master_df.to_csv('master.csv', index=False)

# %% [markdown]
# ### Step 4: Push to GitHub / Share Link with Tech Lead & SME

# %% [markdown]
# ##### This step will be completed outside of Jupyter Notebook. See "Submitting Project" Video Walkthrough from Unit 1 if you have any questions.

# %% [markdown]
# ### Step 5: Record Brief Code Walkthrough / Share Link with Tech Lead & SME

# %% [markdown]
# ##### This step will be completed outside of Jupyter Notebook. See "Submitting Project" Video Walkthrough from Unit 1 if you have any questions.
